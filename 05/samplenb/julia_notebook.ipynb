# %% [markdown]
# # this is a julia notebook

# %%
# this code is python
# it will fail

2 ** 5
# Out:
# LoadError: syntax: use "^" instead of "**"
# while loading In[1], in expression starting on line 4

# %%
# this code is julia
# it will awesome!

2 ^ 6
# Out:
# 64

# %%
Pkg.add("PyPlot")
using PyPlot
x = linspace(0,2*pi,1000); y = sin(3*x + 5*cos(2*x))
plot(x, y, color="red", linewidth=2.0, linestyle="--")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31d5ec470>)
# INFO: Nothing to be done
# INFO: METADATA is out-of-date — you may not have the latest version of PyPlot
# INFO: Use `Pkg.update()` to get the latest versions of your packages
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x31fb02128>
